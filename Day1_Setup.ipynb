# %% [markdown]
# <a href="https://colab.research.google.com/github/SriSurya06/ai-student-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skill sets needed for successful AI implementation, from foundational data work to strategic innovation:
#
# *   **Foundational Data Management:** The base layer, focused on collecting, cleaning, storing, and preparing quality data as the bedrock for all AI initiatives.
# *   **Model Engineering & MLOps:** Encompasses developing, training, and optimizing AI models, followed by their robust deployment, monitoring, and maintenance in production environments.
# *   **Strategic Business Integration:** Focuses on aligning AI solutions with business objectives, identifying use cases, ensuring ethical considerations, and measuring tangible value and ROI.
# *   **Research & Innovation:** The apex, dedicated to pushing the boundaries of AI through novel algorithms, theoretical advancements, and exploratory, future-oriented projects.
